# %%
import pandas as pd

# %%
data=pd.read_csv('/content/heights.csv')
data.head()
# Out:
#     name  height
# 0  mohan     5.9
# 1  maria     5.2
# 2  sakib     5.1
# 3    tao     5.5
# 4  virat     4.9

# %%
max_height=data['height'].quantile(0.95)
max_height
# Out:
# np.float64(9.689999999999998)

# %%
data[data['height']>max_height]
# Out:
#     name  height
# 9  imran    14.5

# %%
min_height=data['height'].quantile(0.05)
min_height
# Out:
# np.float64(3.6050000000000004)

# %%
data[data['height']<min_height]
# Out:
#       name  height
# 12  yoseph     1.2

# %%
data[(data['height']<max_height) & (data['height']>min_height)]
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 10     jose     6.1
# 11  deepika     5.6
# 13    binod     5.5
